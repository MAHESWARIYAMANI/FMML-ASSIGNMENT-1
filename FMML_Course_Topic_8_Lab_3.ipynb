# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHESWARIYAMANI/FMML-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-27 07:58:51--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   223MB/s    in 0.3s
#
# 2023-05-27 07:58:53 (223 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22758  1706.00182v1  Minimizing the empirical risk is a popular tra...  stat
# 1859   1711.05448v1  Recurrent neural network (RNN) language models...  stat
# 28246  1705.10784v1  We propose in this paper a novel two-stage Pro...    cs
# 7580   1802.03938v1  Machine learning has played an important role ...  stat
# 40784   1401.4128v1  The purpose of this study is to optimize the s...    cs
# ...             ...                                                ...   ...
# 35786   1208.1184v1  In mechanism design it is typical to impose in...    cs
# 32923  1511.05641v4  We introduce techniques for rapidly transferri...    cs
# 12569  1803.00491v1  Multilayer graphs encode different kind of int...  stat
# 2622   1611.07054v1  Survival analysis is a fundamental tool in med...    cs
# 21626   1204.1795v1  We consider to learn a causal ordering of vari...  stat
#
#                                                    title  year  \
# 22758    Efficient learning with robust gradient descent  2017
# 1859   Lattice Rescoring Strategies for Long Short Te...  2017
# 28246  PCM-TV-TFV: A Novel Two Stage Framework for Im...  2017
# 7580   Revisiting the Vector Space Model: Sparse Weig...  2018
# 40784  Towards the selection of patients requiring IC...  2014
# ...                                                  ...   ...
# 35786  Payment Rules through Discriminant-Based Class...  2012
# 32923  Net2Net: Accelerating Learning via Knowledge T...  2015
# 12569  The Power Mean Laplacian for Multilayer Graph ...  2018
# 2622   An Efficient Training Algorithm for Kernel Sur...  2016
# 21626  Estimation of causal orders in a linear non-Ga...  2012
#
#                                                 keywords
# 22758  [minimizing, empirical, observations, generali...
# 1859   [recurrent, outperform, traditional, recogniti...
# 28246  [projection, correction, framework, reconstruc...
# 7580   [important, information, retrieval, documents,...
# 40784  [selection, prophylactic, cardioverter, defibr...
# ...                                                  ...
# 35786  [mechanism, incentive, compatibility, mechanis...
# 32923  [introduce, techniques, transferring, informat...
# 12569  [multilayer, different, interactions, multilay...
# 2622   [fundamental, predictors, efficient, optimisat...
# 21626  [variables, consistently, assumptions, estimat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22758    [minimizing, empirical, observations, generali...
# 1859     [recurrent, outperform, traditional, recogniti...
# 28246    [projection, correction, framework, reconstruc...
# 7580     [important, information, retrieval, documents,...
# 40784    [selection, prophylactic, cardioverter, defibr...
#                                ...
# 10808    [usefulness, specifically, representing, diffe...
# 16179    [different, questions, community, answering, c...
# 7583     [empirically, contextual, exploration, encodin...
# 30281    [complication, amputation, approaches, treatme...
# 14271    [exploitation, exploration, decisions, evoluti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8727 words.
# Out of those 4578 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cb3dd345-924f-431e-a770-9a2079c832b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb3dd345-924f-431e-a770-9a2079c832b5")) {                    Plotly.newPlot(                        "cb3dd345-924f-431e-a770-9a2079c832b5",                        [{"x":["iterative","constructs","minimizing","approximation","efficiently","performance","efficient","stringent","requirements","generalizing","empirical","introduce","procedure","observations","probability","resources","generalize","algorithm","computationally","strategies","integrate","expensive","rescoring","outperform","traditional","recurrent","recognizers","algorithms","challenging","recognition","underlying","correction","projection","motivated","reconstruction","framework","continuous","demonstrate","presented","optimization","numerical","minimizes","transformed","functional","consisting","classical","measurements","regularity","variation","corresponding","advantages","fractional","projected","represented","important","revisiting","documents","implementation","generalization","classifiers","generally","extremely","footprint","particular","retrieval","classification","candidate","furthermore","relevance","representer","classifier","information","equivalent","technique","candidates","physiological","decomposition","combinations","optimized","complexity","automatic","myocardial","relatively","evaluated","predictive","recordings","criterion","substrate","performances","specificity","prediction","monitoring","thresholded","autonomic","availability","requiring","selection","according","essential","currently","discrimination","extracted","prevention","improving","negatives","capitalizes","variables","structure","splitting","arrhythmia","forecasts","estimation","conditional","recommend","preference","targeting","identifying","predicted","viewpoints","exploitation","coefficients","personalized","distributed","recommendation","uncertainties","diversity","outperformed","exceptional","computational","providers","experiences","contextual","posterior","serendipity","efficiency","successful","exploration","uncertainty","diversified","variability","estimator","structural","phenotype","transition","hybridization","heuristic","performed","evolutionary","including","investigate","comparable","considered","threefold","extensive","experimental","influence","generated","following","computing","relaxation","arbitrary","integrality","combinatorial","sequential","programming","assignment","graphical","assumption","termination","posteriori","applications","constructed","interpretation","propagation","contractions","respective","expansions","distribution","celebrated","guarantees","systematically","dimension","arguments","illustrate","relationship","simulation","estimators","geometrical","principal","components","characterization","theoretical","populations","facilitates","multivariate","predictor","specifically","unsupervised","induction","effectively"],"y":[68,21,45,112,148,907,421,4,44,8,156,332,137,82,174,61,48,855,95,101,43,67,3,102,155,138,8,620,267,390,121,21,42,71,96,544,103,580,181,346,85,17,28,43,41,89,48,7,61,127,82,3,15,67,344,8,64,136,106,105,56,46,7,249,99,503,51,177,41,2,138,706,45,227,32,8,67,36,52,213,177,2,58,131,53,8,50,3,41,12,214,31,3,1,22,57,168,116,63,43,17,116,4,110,4,3,121,340,14,1,2,202,82,9,29,7,78,49,13,18,43,20,112,33,13,36,22,2,297,5,10,40,35,1,167,70,57,79,2,24,28,74,3,46,2,61,116,49,251,113,109,151,5,180,441,60,167,95,142,20,77,1,43,79,126,29,44,60,8,14,470,63,63,71,3,20,8,222,5,67,20,55,28,77,78,83,15,13,35,105,40,150,15,15,20,14,174,140,23,113],"type":"bar"},{"x":["iterative","constructs","minimizing","approximation","efficiently","performance","efficient","stringent","requir ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4578,), (4578, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Action</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>via</span> <span style=''>Concepts</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4565217391304348);'>Attributes</span> <br/><br/><span style=''>Classes</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>images</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>follow</span> <span style=''>long</span> <span style=''>tail</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>This</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>problematic</span> <span style=''>when</span> <span style=''>there</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>insufficient</span> <span style=''>training</span> <span style=''>examples</span> <span style=''>for</span> <span style=''>rare</span> <span style=''>classes</span> <span style=''>This</span> <span style=''>effect</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>emphasized</span> <span style=''>in</span> <span style=''>compound</span> <span style=''>classes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>involving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5172413793103449);'>conjunction</span> <span style=''>of</span> <span style=''>several</span> <span style=''>concepts</span> <span style=''>such</span> <span style=''>as</span> <span style=''>those</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appearing</span> <span style=''>in</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.6421052631578947);'>recognition</span> <span style=''>datasets</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>by</span> <span style=''>learning</span> <span style=''>how</span> <span style=''>to</span> <span style=''>utilize</span> <span style=''>common</span> <span style=''>visual</span> <span style=''>concepts</span> <span style=''>which</span> <span style=''>are</span> <span style=''>readily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>We</span> <span style=''>detect</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prominent</span> <span style=''>concepts</span> <span style=''>in</span> <span style=''>images</span> <span style=''>and</span> <span style=''>use</span> <span style=''>them</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>target</span> <span style=''>labels</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>using</span> <span style=''>visual</span> <span style=''>features</span> <span style=''>directly</span> <span style='background-color:rgba(0, 255, 0, 0.3503184713375797);'>combining</span> <span style=''>tools</span> <span style=''>from</span> <span style=''>vision</span> <span style=''>and</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.48448687350835323);'>processing</span> <span style=''>We</span> <span style=''>validate</span> <span style=''>our</span> <span style=''>method</span> <span style=''>on</span> <span style=''>the</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>HICO</span> <span style=''>dataset</span> <span style=''>reaching</span> <span style=''>a</span> <span style=''>mAP</span> <span style=''>of</span> <span style=''>3154</span> <span style=''>and</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discriminant</span> <span style=''>Analysis</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Regularized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>analysis</span> <span style=''>(RDA)</span> <span style=''>proposed</span> <span style=''>by</span> <span style=''>Friedman</span> <span style=''>(1989)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>widely</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>that</span> <span style=''>lacks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impractical</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>called</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>RDA</span> <span style=''>(HDRDA)</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>the</span> <span style=''>small</span> <span style=''>sample</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>setting</span> <span style=''>For</span> <span style=''>HDRDA</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>each</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regardless</span> <span style=''>of</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributes</span> <span style=''>to</span> <span style=''>the</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>that</span> <span style=''>borrows</span> <span style=''>from</span> <span style=''>the</span> <span style=''>pooled</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>HDRDA</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>in</span> <span style=''>a</span> <span style=''>reduced</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximately</span> <span style=''>equal</span> <span style=''>to</span> <span style=''>the</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style=''>Hashing</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Scale</span> <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>Multitask</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>evidence</span> <span style=''>suggests</span> <span style=''>that</span> <span style=''>hashing</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style=''>strategy</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3108108108108109);'>dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.8289473684210527);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>tail</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>feature</span> <span style=''>hashing</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4244604316546763);'>interaction</span> <span style=''>between</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subspaces</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>negligible</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>feasibility</span> <span style=''>of</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.4675540765391015);'>experimental</span> <span style=''>results</span> <span style=''>for</span> <span style=''>a</span> <span style=''>new</span> <span style=''>use</span> <span style=''>case</span> <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>multitask</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>hundreds</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thousands</span> <span style=''>of</span> <span style=''>tasks</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reinforced</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <span style=''>(ORGAN)</span> <span style=''>for</span> <span style=''>Sequence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generation</span> <span style=''>Models</span> <br/><br/><span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>tasks</span> <span style=''>besides</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sample</span> <span style=''>based</span> <span style=''>on</span> <span style=''>previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>one</span> <span style=''>would</span> <span style=''>often</span> <span style=''>like</span> <span style=''>to</span> <span style=''>give</span> <span style=''>hints</span> <span style=''>to</span> <span style=''>the</span> <span style=''>model</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>bias</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>towards</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style=''>metrics</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>that</span> <span style=''>combines</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <span style=''>(GANs)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>(RL)</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accomplish</span> <span style=''>exactly</span> <span style=''>that</span> <span style=''>While</span> <span style=''>RL</span> <span style=''>biases</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>process</span> <span style=''>towards</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>metrics</span> <span style=''>the</span> <span style=''>GAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>of</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>function</span> <span style=''>ensures</span> <span style=''>that</span> <span style=''>the</span> <span style=''>model</span> <span style=''>still</span> <span style=''>remembers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>data</span> <span style=''>We</span> <span style=''>build</span> <span style=''>upon</span> <span style=''>previous</span> <span style=''>results</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporated</span> <span style=''>GANs</span> <span style=''>and</span> <span style=''>RL</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>sequence</span> <span style=''>data</span> <span style=''>and</span> <span style=''>test</span> <span style=''>this</span> <span style=''>model</span> <span style=''>in</span> <span style=''>several</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1301418439716312)
# 	knowledge (0.125177304964539)
# 	segmentation (0.06595744680851064)
# 	information (0.250354609929078)
# 	processing (0.11028368794326242)
# 	different (0.26099290780141843)
# 	detection (0.1226950354609929)
# 	experimental (0.15638297872340426)
# 	convolutional (0.13297872340425532)
# 	recognition (0.13829787234042554)
#
# Some Statistics words are:
# 	variational (0.10707070707070707)
# 	algorithm (0.39545454545454545)
# 	variables (0.13787878787878788)
# 	theoretical (0.151010101010101)
# 	estimation (0.17474747474747473)
# 	statistical (0.15808080808080807)
# 	distribution (0.19292929292929292)
# 	dimensional (0.18787878787878787)
# 	inference (0.21363636363636362)
# 	regression (0.18787878787878787)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="99664e5d-ec15-4726-ba87-87e870af1ddb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99664e5d-ec15-4726-ba87-87e870af1ddb")) {                    Plotly.newPlot(                        "99664e5d-ec15-4726-ba87-87e870af1ddb",                        [{"x":["iterative","constructs","minimizing","approximation","efficiently","performance","efficient","stringent","requirements","generalizing","empirical","introduce","procedure","observations","probability","resources","generalize","algorithm","computationally","strategies","integrate","expensive","rescoring","outperform","traditional","recurrent","recognizers","algorithms","challenging","recognition","underlying","correction","projection","motivated","reconstruction","framework","continuous","demonstrate","presented","optimization","numerical","minimizes","transformed","functional","consisting","classical","measurements","regularity","variation","corresponding","advantages","fractional","projected","represented","important","revisiting","documents","implementation","generalization","classifiers","generally","extremely","footprint","particular","retrieval","classification","candidate","furthermore","relevance","representer","classifier","information","equivalent","technique","candidates","physiological","decomposition","combinations","optimized","complexity","automatic","myocardial","relatively","evaluated","predictive","recordings","criterion","substrate","performances","specificity","prediction","monitoring","thresholded","autonomic","availability","requiring","selection","according","essential","currently","discrimination","extracted","prevention","improving","negatives","capitalizes","variables","structure","splitting","arrhythmia","forecasts","estimation","conditional","recommend","preference","targeting","identifying","predicted","viewpoints","exploitation","coefficients","personalized","distributed","recommendation","uncertainties","diversity","outperformed","exceptional","computational","providers","experiences","contextual","posterior","serendipity","efficiency","successful","exploration","uncertainty","diversified","variability","estimator","structural","phenotype","transition","hybridization","heuristic","performed","evolutionary","including","investigate","comparable","considered","threefold","extensive","experimental","influence","generated","following","computing","relaxation","arbitrary","integrality","combinatorial","sequential","programming","assignment","graphical","assumption","termination","posteriori","applications","constructed","interpretation","propagation","contractions","respective","expansions","distribution","celebrated","guarantees","systematically","dimension","arguments","illustrate","relationship","simulation","estimators","geometrical","principal","components","characterization","theoretical","populations","facilitates","multivariate","predictor","specifically","unsupervised","induction","effectively","normality","reduction","sparsification","specifics","significant","variational","eliminates","sentiment","independently","transforms","flexibility","typically","denoising","excellent","properties","sparsifying","convolutional","demonstrated","transform","benefiting","redundant","restoration","representations","neighboring","additional","identified","categories","offensive","classifications","promising","technologies","attributes","introduced","association","clustering","gathering","basketball","positions","defensive","different","autonomous","optimizing","variationally","forecasting","therefore","inference","evaluation","propagate","resulting","effective","dimensions","gracefully","completion","decompositions","applicability","dictionary","randomized","interp ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	gracefully
# 	nullspace
# 	autocorrelation
# 	unavoidably
# 	campaigns
# 	integrals
# 	embarrassingly
# 	stepsizes
# 	parallelizing
# 	polymorphisms
# 	reparameterized
# 	rescaling
# 	contributed
# 	nonconvexity
# 	prioritization
# 	conjugacy
# 	sacrifice
# 	transcriptional
# 	ancestral
# 	microbial
# Some words which never appear in Statistics papers:
# 	substrate
# 	capitalizes
# 	termination
# 	gathering
# 	perceptions
# 	anisotropy
# 	identities
# 	observers
# 	cooperation
# 	crossover
# 	syntactic
# 	syntactically
# 	functionally
# 	microsurgery
# 	laparoscopic
# 	paraphrase
# 	sentential
# 	paraphrases
# 	alternated
# 	alternatingly

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.050826774055769e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
